# %%
import spacy
import re
import textstat
import numpy as np
import pandas as pd
import sklearn.ensemble
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from nltk import WhitespaceTokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy import sparse

# %% [markdown]
# ## Loading journal text entries

# %%
users = pd.read_csv('/Users/afrah/Desktop/catchingfeels/data/users.csv')
journals = pd.read_csv('/Users/afrah/Desktop/catchingfeels/data/journals.csv')

# %%
journals.head()

# %% [markdown]
# Dropping NAN entries in sentiment/journal/date

# %%
journals_sub = journals.dropna(subset=['sentiment', 'journal', 'date'])
journals_sub['sentiment_level'] = journals_sub[[
    'sentiment'
]].apply(lambda x: pd.cut(x, [-np.inf, -.5, .5, np.inf],
                          labels=['negative', 'neutral', 'positive']))
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Feature Engineering
#
# ### Time features
#
# Time of day, month, seasons

# %%
journals_sub['date'] = pd.to_datetime(journals_sub['date'])
journals_sub['year'] = pd.Series(journals_sub['date'].dt.year,
                                 dtype='category')
journals_sub['day'] = journals_sub['date'].dt.day_name()
journals_sub['month'] = journals_sub['date'].dt.month_name()
journals_sub['month_trans'] = np.cos(
    (journals_sub['date'].dt.month - 6.0) / 6.0)
journals_sub['timeofday'] = journals_sub['date'].dt.hour
journals_sub['timeofday_trans'] = np.cos(
    (journals_sub['date'].dt.hour - 12.0) / 12.0)
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
plt.figure(figsize=(15, 8))
journals_sub.hist(figsize=(20, 10),
                  ylabelsize=15,
                  xlabelsize=15,
                  xrot=20,
                  bins=20,
                  edgecolor='white')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2f126c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1aa8e37690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2d0b8b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2f15fbd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2eb850d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a306aea90>]],
#       dtype=object)

# %%
sns.countplot(x='year',
              hue='sentiment_level',
              data=journals_sub,
              orient='horizontal',
              edgecolor='white')

# %% [markdown]
# #### Time of day

# %%
plt.figure(figsize=(10, 8))
# plt.subplot(2,2,1)
ax = sns.boxplot(x="sentiment_level", y='timeofday_trans', data=journals_sub)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20)

# plt.subplot(2,2,3)
# plt.scatter(x=np.arange(24), y= np.cos((np.arange(24)-12)/12))
# plt.axhline(y=0.75)
# Out:
# [Text(0, 0, 'neutral'), Text(0, 0, 'negative'), Text(0, 0, 'positive')]

# %%
plt.figure(figsize=(15, 15))
plt.subplot(3, 1, 1)
ax = sns.boxplot(x="sentiment_level", y='month_trans', data=journals_sub)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20)

plt.subplot(3, 1, 2)
ax = sns.boxplot(y="sentiment", x='month', data=journals_sub)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20)

plt.subplot(3, 1, 3)
plt.scatter(x=np.arange(12), y=np.cos((np.arange(12) - 6) / 6))

# %% [markdown]
# #### Seasons
#
# Do Seasons influence mood predictions? Especially in the context of seasonal affective disorders

# %%
Winter = ['December', 'January', 'February']
Spring = ['March', 'April', 'May']
Summer = ['June', 'July', 'August']
Fall = ['September', 'October', 'November']

seasons = dict(
    zip(Winter + Spring + Summer + Fall,
        ['Winter'] * 3 + ['Spring'] * 3 + ['Summer'] * 3 + ['Fall'] * 3))
journals_sub['season'] = journals_sub['month'].map(seasons)

seasons_color = dict(
    zip(Winter + Spring + Summer + Fall,
        ['skyblue'] * 3 + ['lightgreen'] * 3 + ['#FFD43B'] * 3 + ['Red'] * 3))
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# Winter seems to have the lowest mood predictions; though seem insignificant

# %%
plt.figure(figsize=(15, 8))
ax = sns.boxplot(y="sentiment",
                 x='season',
                 data=journals_sub,
                 palette={
                     'Winter': 'skyblue',
                     'Fall': 'Red',
                     'Spring': 'lightgreen',
                     'Summer': '#FFD43B'
                 })
ax.set_xticklabels(ax.get_xticklabels())
# Out:
# [Text(0, 0, 'Spring'),
#  Text(0, 0, 'Summer'),
#  Text(0, 0, 'Winter'),
#  Text(0, 0, 'Fall')]

# %% [markdown]
# ### Content-based features
#
# #### Personal and Non-personal pronouns

# %%
def get_pprn(doc):
    inner_pprn = ('i', 'me', 'my', 'mine', 'myself')
    outer_pprn = ('we', 'you', 'your', 'yourself', 'yours', 'yourselves', 'he',
                  'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
                  'they', 'them', 'their', 'theirs', 'themselves')
    inner_count = 0
    outer_count = 0

    for token in doc:
        if token.text in inner_pprn:
            inner_count += 1
        elif token.text in outer_pprn:
            outer_count += 1
    return inner_count, outer_count

# %%
journals_sub['word_len'] = journals_sub['journal'].apply(lambda x: len(x.split(' ')))
journals_sub['word_len'].plot(kind='hist', logy=True, edgecolor='white')

# print(sum(journals_sub['word_len']>50))
plt.xlabel('# Words in Entry')
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, '# Words in Entry')

# %%
nlp = spacy.load("en_core_web_sm")
i_count_all = []
o_count_all = []

for entry in journals_sub['journal']:
    doc = nlp(entry.lower())
    i_count, o_count = get_pprn(doc)
    i_count_all.append(i_count)
    o_count_all.append(o_count)

# %%
journals_sub['inner_pprn'] = np.array(i_count_all)
journals_sub['outer_pprn'] = np.array(o_count_all)
journals_sub[
    'sum_pprn'] = journals_sub['outer_pprn'] + journals_sub['inner_pprn']
journals_sub[
    'inner_frac'] = journals_sub['inner_pprn'] / journals_sub['sum_pprn']
journals_sub['inner_frac'] = journals_sub['inner_frac'].fillna(0)
journals_sub[
    'outer_frac'] = journals_sub['outer_pprn'] / journals_sub['sum_pprn']
journals_sub['outer_frac'] = journals_sub['outer_frac'].fillna(0)
journals_sub['pprn_ratio'] = np.array(i_count_all) / (np.array(o_count_all) +
                                                      1)
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
plt.figure(figsize=(20, 10))
sns.pairplot(corner=True,
             data=journals_sub[[
                 'pprn_ratio', 'inner_frac', 'outer_frac', 'sum_pprn',
                 'sentiment_level'
             ]],
             hue='sentiment_level')
plt.ylabel(['P', 'A', 'B'])
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# Text(427.03802897135415, 0.5, "['P', 'A', 'B']")

# %%
sns.boxplot(x='sentiment_level',
            y='pprn_ratio',
            data=journals_sub[journals_sub['sum_pprn'] > 20])
plt.ylabel('Personal: Non-personal pronouns')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
stop_words = set(stopwords.words('english'))

filtered_sentences = journals_sub['journal'].apply(
    lambda x: ' '.join([i for i in WhitespaceTokenizer().tokenize(x)]))

# %%
corpus = journals_sub['journal']
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'),
                             token_pattern=r'(?u)\b[A-Za-z]+\b')
mat = vectorizer.fit_transform(corpus)

# %% [markdown]
# #### Readability scores

# %%
journals_sub['polysyllable_count'] = journals_sub['journal'].apply(
    lambda x: textstat.textstat.polysyllabcount(x))
journals_sub['difficult_words'] = journals_sub['journal'].apply(
    lambda x: textstat.textstat.difficult_words(x))
journals_sub['cl_index'] = journals_sub['journal'].apply(
    lambda x: textstat.textstat.coleman_liau_index(x))
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.pairplot(data=journals_sub[[
    'polysyllable_count', 'difficult_words', 'cl_index', 'word_len'
,'sentiment']],
             corner=True)

# %% [markdown]
# ### User behavior features

# %% [markdown]
# #### Users-frequency of posting

# %%
journals_sub['user'] = journals_sub['path'].apply(
    lambda x: re.sub('"', '',
                     x.split(',')[1].strip()))
# Out:
# /Users/afrah/miniconda3/envs/test/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Number of journal entries varies per user
plt.figure(figsize=(10, 8))
plt.hist(journals_sub['user'].value_counts(), bins=20, edgecolor='white')
plt.yscale('log')
plt.xlabel('# Journal Entries')
plt.ylabel('# Users')
# Out:
# Text(0, 0.5, '# Users')

# %%
# Variance in sentiment scores may also be associated with # entries by a user
plt.hexbin(y=journals_sub.groupby('user').mean()['sentiment'],
           x=journals_sub['user'].value_counts(),
           gridsize=20,
           cmap='Blues',
           bins='log')
plt.xlabel('# Entries by user')
plt.ylabel('Mean(Sentiment)')
plt.colorbar()

# %%
# save all journal entries
# journals_sub.to_csv('../data/all_journals.csv', index=False)

# %% [markdown]
# ## Audio features

# %%
df = pd.read_csv('/Users/afrah/Desktop/catchingfeels/data/audio_features13030.csv')

# %%
sns.pairplot(data=df, corner=True)

# %%
journals_sub.columns
# Out:
# Index(['recordingname', 'prompt', 'mood', 'sentiment', 'journal', 'date',
#        'path', 'sentiment_level', 'year', 'day', 'month', 'month_trans',
#        'timeofday', 'timeofday_trans', 'season', 'word_len', 'inner_pprn',
#        'outer_pprn', 'sum_pprn', 'inner_frac', 'outer_frac', 'pprn_ratio',
#        'polysyllable_count', 'difficult_words', 'cl_index', 'user'],
#       dtype='object')

# %%
# journals_sub = journals_sub[journals_sub['word_len']>=50]

# %%
tmp = pd.read_csv('../data/')
tmp.columns
# Out:
# Index(['recordingname', 'prompt', 'mood', 'sentiment', 'journal', 'duration',
#        'date', 'path'],
#       dtype='object')

# %%
journals_merge = journals_sub[['sentiment', 'date', 'recordingname', 'user',
                              'sentiment_level', 'pprn_ratio', 'sum_pprn',
                              'inner_frac', 'word_len', 'journal',
                              'timeofday_trans', 'season', 'month_trans']].merge(df,
                                        left_on='recordingname',
                                        right_on='recordingname')
journals_merge['wps'] = journals_merge['word_len'] / journals_merge['duration']

# %%
# journals_merge.to_csv('../data/all_journals_audio_merged.csv', index=False)

# %% [markdown]
# ## Putting it altogether

# %%
X = journals_merge[['timeofday', 'month_trans', 'sum_pprn', 'pprn_ratio',
    'wps', 'season', 'median_pitch',
    'max_amp','var_zcr']]
X_dums = pd.get_dummies(X)
y = journals_merge['sentiment']

# %%
X = journals_sub[[
    'year', 'day', 'timeofday', 'month_trans', 'sum_pprn', 'pprn_ratio',
    'word_len', 'season', 'inner_frac'
]]
X_dums = pd.get_dummies(X)
y = journals_sub['sentiment_level']

# %%
num_feats = X_dums.values

training_data = sparse.hstack((mat, num_feats))

# %%
num_feats = X_dums.values
training_data = sparse.hstack((mat, num_feats))

# %% [markdown]
# ## Prediction
# ### Train-Test splits

# %%
X_train, X_test, y_train, y_test = train_test_split(
    training_data,
    y,
    test_size=0.30,
    random_state=42)

# %%
reg = sklearn.ensemble.RandomForestRegressor().fit(X_train, y_train)
# reg = sklearn.ensemble.RandomForestClassifier().fit(X_train, y_train)

# %%
# plt.figure(figsize=(20, 10))
y_pred = reg.predict(X_test)
# cm = sklearn.metrics.confusion_matrix(y_test, y_pred)
# ax = ConfusionMatrixDisplay(cm, display_labels = y_test.unique()).plot()
# print(sklearn.metrics.accuracy_score(y_test, y_pred))
# print(sklearn.metrics.precision_score(y_test, y_pred, average='weighted'))

plt.figure(figsize=(20, 10))
y_pred = reg.predict(X_test)
print('R2 score: %s' % sklearn.metrics.r2_score(y_test, y_pred))
print('MSE score: %s' % sklearn.metrics.mean_squared_error(y_test, y_pred))
print('%var. exp. score ', sklearn.metrics.explained_variance_score(y_test, y_pred))
# Out:
# R2 score: 0.2424780281846345
# MSE score: 0.21335623810853485
# %var. exp. score  0.24406861758114096

# %%
y_test
# Out:
# 9841      neutral
# 379       neutral
# 6032      neutral
# 3693     negative
# 4540     positive
#            ...
# 2485      neutral
# 4351     positive
# 12966    negative
# 11808    positive
# 4301     positive
# Name: sentiment_level, Length: 3909, dtype: object

# %%
feature_names = vectorizer.get_feature_names() + list(X_dums.columns)
features_x = []
features_y = []
for i in np.where(reg.feature_importances_ > 0.01)[0]:
    features_x += [feature_names[i]]
    features_y += [reg.feature_importances_[i]]
#     print(feature_names[i], reg.feature_importances_[i])
# print(features_sub)

# %%
sns.barplot(x=features_y, y=features_x)
plt.xlabel('Feature importance')
# Out:
# Text(0.5, 0, 'Feature importance')

# %%
# reg = sklearn.ensemble.GradientBoostingClassifier(
#                                 n_estimators=1000, max_depth=10,
#                                 learning_rate=.4, min_samples_leaf=10,
#                                 min_samples_split=9).fit(X_train,y_train)

# %%
# y_pred = reg.predict(X_test)
# cm = sklearn.metrics.confusion_matrix(y_test, y_pred)
# ConfusionMatrixDisplay(cm, display_labels=y_test.unique()).plot()
# print(sklearn.metrics.accuracy_score(y_test, y_pred))
# print(sklearn.metrics.precision_score(y_test, y_pred, average='weighted'))

# %%
# reg = DecisionTreeClassifier().fit(X_train,y_train)
# y_pred = reg.predict(X_test)
# cm = sklearn.metrics.confusion_matrix(y_test, y_pred)
# ConfusionMatrixDisplay(cm, display_labels=y_test.unique()).plot()
# print(sklearn.metrics.accuracy_score(y_test, y_pred))
# print(sklearn.metrics.precision_score(y_test, y_pred, average='weighted'))
